# %% [markdown]
# ## **Day 1** Basics of Python

# %%
print ("Hello World")
print ("Pratistha Bhandari")
s= "Pratistha Bhandari"
print(s)
a= 20.5
b="Hi"
c="pratistha"
d=3000.40
print(a,b,c,d)
print("Kritim", end="@")
print ("Mind Technology")
# Out:
# Hello World
# Pratistha Bhandari
# Pratistha Bhandari
# 20.5 Hi pratistha 3000.4
# Kritim@MInd Technology

# %%
print ("apple", "mango","banana", sep="/")
# Out:
# apple/mango/banana

# %%
print("pratistha","kritim",sep=".", end="@")
print("gmail","com", sep=".")
# Out:
# pratistha.kritim@gmail.com

# %%
name= "Pratistha"
age="20"
print(f"My name is {name}. I am {age} years old")
# Out:
# My name is Pratistha. I am 20 years old

# %%
a= int(input ("Enter value of a"))
print(a)
b= int(input ("Enter value of b"))
print (b)
sum= a+b
print (sum)

x,y= int(input("Enter value of x and y"))
# Out:
# Enter value of a 2
# 2
# Enter value of b 3
# 3
# 5
# Enter value of x and y 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       5 sum= a+b
#       6 print (sum)
# ----> 8 x,y= int(input("Enter value of x and y"))
#
# TypeError: cannot unpack non-iterable int object

# %%
x,y= input("Enter value of x and y").split()
print("The value of x: ",x)
print("The value of y:",y)
# Out:
# Enter value of x and y 1 2
# The value of x:  1
# The value of y: 2

# %%
x
